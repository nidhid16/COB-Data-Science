# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#read csv file
df = pd.read_csv("C:\\Users\\Nidhi Davane\\Documents\\dataset - netflix1 (1).csv")

# %%
df.head(10)
# Out:
#   show_id     type                             title             director  \
# 0      s1    Movie              Dick Johnson Is Dead      Kirsten Johnson
# 1      s3  TV Show                         Ganglands      Julien Leclercq
# 2      s6  TV Show                     Midnight Mass        Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl        Bruno Garotti
# 4      s8    Movie                           Sankofa         Haile Gerima
# 5      s9  TV Show     The Great British Baking Show      Andy Devonshire
# 6     s10    Movie                      The Starling       Theodore Melfi
# 7    s939    Movie   Motu Patlu in the Game of Zones          Suhas Kadav
# 8     s13    Movie                      Je Suis Karl  Christian Schwochow
# 9    s940    Movie          Motu Patlu in Wonderland          Suhas Kadav
#
#           country date_added  release_year rating   duration  \
# 0   United States  9/25/2021          2020  PG-13     90 min
# 1          France  9/24/2021          2021  TV-MA   1 Season
# 2   United States  9/24/2021          2021  TV-MA   1 Season
# 3          Brazil  9/22/2021          2021  TV-PG     91 min
# 4   United States  9/24/2021          1993  TV-MA    125 min
# 5  United Kingdom  9/24/2021          2021  TV-14  9 Seasons
# 6   United States  9/24/2021          2021  PG-13    104 min
# 7           India   5/1/2021          2019  TV-Y7     87 min
# 8         Germany  9/23/2021          2021  TV-MA    127 min
# 9           India   5/1/2021          2013  TV-Y7     76 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries
# 3                 Children & Family Movies, Comedies
# 4   Dramas, Independent Movies, International Movies
# 5                       British TV Shows, Reality TV
# 6                                   Comedies, Dramas
# 7  Children & Family Movies, Comedies, Music & Mu...
# 8                       Dramas, International Movies
# 9         Children & Family Movies, Music & Musicals

# %%
df.info
# Out:
# <bound method DataFrame.info of      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# 0     United States   9/25/2021          2020  PG-13     90 min
# 1            France   9/24/2021          2021  TV-MA   1 Season
# 2     United States   9/24/2021          2021  TV-MA   1 Season
# 3            Brazil   9/22/2021          2021  TV-PG     91 min
# 4     United States   9/24/2021          1993  TV-MA    125 min
# ...             ...         ...           ...    ...        ...
# 8785         Turkey   1/17/2017          2016  TV-PG  2 Seasons
# 8786  United States   9/13/2018          2016  TV-Y7  3 Seasons
# 8787       Pakistan  12/15/2016          2012  TV-PG   1 Season
# 8788       Pakistan   6/23/2018          2016   TV-Y   1 Season
# 8789       Pakistan    6/7/2018          2016  TV-Y7   1 Season
#
#                                               listed_in
# 0                                         Documentaries
# 1     Crime TV Shows, International TV Shows, TV Act...
# 2                    TV Dramas, TV Horror, TV Mysteries
# 3                    Children & Family Movies, Comedies
# 4      Dramas, Independent Movies, International Movies
# ...                                                 ...
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# 8788                                           Kids' TV
# 8789                                           Kids' TV
#
# [8790 rows x 10 columns]>

# %%
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# 0     United States   9/25/2021          2020  PG-13     90 min
# 1            France   9/24/2021          2021  TV-MA   1 Season
# 2     United States   9/24/2021          2021  TV-MA   1 Season
# 3            Brazil   9/22/2021          2021  TV-PG     91 min
# 4     United States   9/24/2021          1993  TV-MA    125 min
# ...             ...         ...           ...    ...        ...
# 8785         Turkey   1/17/2017          2016  TV-PG  2 Seasons
# 8786  United States   9/13/2018          2016  TV-Y7  3 Seasons
# 8787       Pakistan  12/15/2016          2012  TV-PG   1 Season
# 8788       Pakistan   6/23/2018          2016   TV-Y   1 Season
# 8789       Pakistan    6/7/2018          2016  TV-Y7   1 Season
#
#                                               listed_in
# 0                                         Documentaries
# 1     Crime TV Shows, International TV Shows, TV Act...
# 2                    TV Dramas, TV Horror, TV Mysteries
# 3                    Children & Family Movies, Comedies
# 4      Dramas, Independent Movies, International Movies
# ...                                                 ...
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# 8788                                           Kids' TV
# 8789                                           Kids' TV
#
# [8790 rows x 10 columns]

# %%
df["director"] = df["director"].replace("Not Given",np.NaN)
df["country"] = df["country"].replace("Not Given",np.NaN)

# %%
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre              NaN
# 8786   s8798  TV Show                         Zak Storm              NaN
# 8787   s8801  TV Show                Zindagi Gulzar Hai              NaN
# 8788   s8784  TV Show                              Yoko              NaN
# 8789   s8786  TV Show                               YOM              NaN
#
#             country  date_added  release_year rating   duration  \
# 0     United States   9/25/2021          2020  PG-13     90 min
# 1            France   9/24/2021          2021  TV-MA   1 Season
# 2     United States   9/24/2021          2021  TV-MA   1 Season
# 3            Brazil   9/22/2021          2021  TV-PG     91 min
# 4     United States   9/24/2021          1993  TV-MA    125 min
# ...             ...         ...           ...    ...        ...
# 8785         Turkey   1/17/2017          2016  TV-PG  2 Seasons
# 8786  United States   9/13/2018          2016  TV-Y7  3 Seasons
# 8787       Pakistan  12/15/2016          2012  TV-PG   1 Season
# 8788       Pakistan   6/23/2018          2016   TV-Y   1 Season
# 8789       Pakistan    6/7/2018          2016  TV-Y7   1 Season
#
#                                               listed_in
# 0                                         Documentaries
# 1     Crime TV Shows, International TV Shows, TV Act...
# 2                    TV Dramas, TV Horror, TV Mysteries
# 3                    Children & Family Movies, Comedies
# 4      Dramas, Independent Movies, International Movies
# ...                                                 ...
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# 8788                                           Kids' TV
# 8789                                           Kids' TV
#
# [8790 rows x 10 columns]

# %%
df.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.isnull()
# Out:
#       show_id   type  title  director  country  date_added  release_year  \
# 0       False  False  False     False    False       False         False
# 1       False  False  False     False    False       False         False
# 2       False  False  False     False    False       False         False
# 3       False  False  False     False    False       False         False
# 4       False  False  False     False    False       False         False
# ...       ...    ...    ...       ...      ...         ...           ...
# 8785    False  False  False      True    False       False         False
# 8786    False  False  False      True    False       False         False
# 8787    False  False  False      True    False       False         False
# 8788    False  False  False      True    False       False         False
# 8789    False  False  False      True    False       False         False
#
#       rating  duration  listed_in
# 0      False     False      False
# 1      False     False      False
# 2      False     False      False
# 3      False     False      False
# 4      False     False      False
# ...      ...       ...        ...
# 8785   False     False      False
# 8786   False     False      False
# 8787   False     False      False
# 8788   False     False      False
# 8789   False     False      False
#
# [8790 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2588
# country          287
# date_added         0
# release_year       0
# rating             0
# duration           0
# listed_in          0
# dtype: int64

# %%
newdf = df.fillna(" ")
newdf.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
newdf["date_added"] = pd.to_datetime(newdf["date_added"], errors="coerce")
newdf["date_added"] = newdf["date_added"].dt.strftime("%d%m%y")

# %%
missed_dates = newdf["date_added"].isnull().sum()

# %%
#outliers
sns.boxplot(x=newdf["release_year"])
# Out:
# <AxesSubplot:xlabel='release_year'>

# %%
sns.histplot(x=newdf["release_year"],kde=True)
# Out:
# <AxesSubplot:xlabel='release_year', ylabel='Count'>

# %%
newdf["release_year"].describe()
# Out:
# count    8790.000000
# mean     2014.183163
# std         8.825466
# min      1925.000000
# 25%      2013.000000
# 50%      2017.000000
# 75%      2019.000000
# max      2021.000000
# Name: release_year, dtype: float64

# %%
percentile25 = newdf["release_year"].quantile(0.25)
percentile75 = newdf["release_year"].quantile(0.75)

# %%
percentile25, percentile75
# Out:
# (2013.0, 2019.0)

# %%
#Interquartile Range
IQR = percentile75 - percentile25
IQR
# Out:
# 6.0

# %%
upper_limit = percentile75 + 1.5*IQR
lower_limit = percentile25 - 1.5*IQR
print(upper_limit,"- upper_limit")
print(lower_limit,"- lower_limit")
# Out:
# 2025.0 - upper_limit
# 2009.0 - lower_limit

# %%
newdf[newdf["release_year"]>upper_limit]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, country, date_added, release_year, rating, duration, listed_in]
# Index: []

# %%
newdf[newdf["release_year"]<lower_limit]
# Out:
#      show_id     type                                title          director  \
# 4         s8    Movie                              Sankofa      Haile Gerima
# 29       s25    Movie                                Jeans        S. Shankar
# 51       s27    Movie                       Minsara Kanavu       Rajiv Menon
# 53       s23    Movie                      Avvai Shanmughi    K.S. Ravikumar
# 60       s42    Movie                                 Jaws  Steven Spielberg
# ...      ...      ...                                  ...               ...
# 8702   s8232    Movie                             The Bund
# 8743   s8524  TV Show    The Super Mario Bros. Super Show!
# 8746   s8542  TV Show  The Twilight Zone (Original Series)
# 8761   s8645  TV Show                           Twin Peaks
# 8765   s8670  TV Show                        V.R. Troopers
#
#             country date_added  release_year rating  duration  \
# 4     United States     240921          1993  TV-MA       125
# 29            India     210921          1998  TV-14       166
# 51            India     210921          1997  TV-PG       147
# 53                      210921          1996  TV-PG       161
# 60    United States     160921          1975     PG       124
# ...             ...        ...           ...    ...       ...
# 8702      Hong Kong     200918          1983  TV-14       103
# 8743  United States     220516          1989  TV-Y7         1
# 8746  United States     010717          1963  TV-14         4
# 8761  United States     010717          1990  TV-14         2
# 8765  United States     010116          1995   TV-G         2
#
#                                              listed_in
# 4     Dramas, Independent Movies, International Movies
# 29     Comedies, International Movies, Romantic Movies
# 51    Comedies, International Movies, Music & Musicals
# 53                      Comedies, International Movies
# 60          Action & Adventure, Classic Movies, Dramas
# ...                                                ...
# 8702  Action & Adventure, Dramas, International Movies
# 8743                                          Kids' TV
# 8746            Classic & Cult TV, TV Sci-Fi & Fantasy
# 8761      Classic & Cult TV, Crime TV Shows, TV Dramas
# 8765                                          Kids' TV
#
# [717 rows x 10 columns]

# %%
df2 = newdf[newdf["release_year"]>lower_limit]

# %%
df2.shape
# Out:
# (8009, 10)

# %% [markdown]
# # finding outliers

# %%
sns.boxplot(x=df2["release_year"])
# Out:
# <AxesSubplot:xlabel='release_year'>

# %%
sns.histplot(x=df2["release_year"], kde=True)
# Out:
# <AxesSubplot:xlabel='release_year', ylabel='Count'>

# %%
df2["release_year"].describe()
# Out:
# count    8009.000000
# mean     2016.408291
# std         3.637256
# min      2005.000000
# 25%      2015.000000
# 50%      2017.000000
# 75%      2019.000000
# max      2021.000000
# Name: release_year, dtype: float64

# %%
percentile25 = df2["release_year"].quantile(0.25)
percentile75 = df2["release_year"].quantile(0.75)

# %%
percentile25
# Out:
# 2015.0

# %%
IQR = percentile75 - percentile25
IQR
# Out:
# 4.0

# %%
upper_limit = percentile75 + 1.5*IQR
lower_limit = percentile25 - 1.5*IQR
print(upper_limit,"- upper_limit")
print(lower_limit,"- lower_limit")
# Out:
# 2025.0 - upper_limit
# 2009.0 - lower_limit

# %%
df2[df2["release_year"]>upper_limit]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, country, date_added, release_year, rating, duration, listed_in]
# Index: []

# %%
df2[df2["release_year"]<lower_limit]
# Out:
#      show_id     type                                              title  \
# 82       s58    Movie                  Naruto Shippûden the Movie: Bonds
# 84       s60    Movie                        Naruto Shippuden: The Movie
# 86       s62    Movie   Naruto the Movie 2: Legend of the Stone of Gelel
# 87       s63    Movie  Naruto the Movie 3: Guardians of the Crescent ...
# 181     s130    Movie                                 An Unfinished Life
# ...      ...      ...                                                ...
# 8693   s8175  TV Show                                     That '70s Show
# 8714   s8317  TV Show                                The Future of Water
# 8736   s8477  TV Show                        The Real Football Factories
# 8748   s8552  TV Show       The War: A Film by Ken Burns and Lynn Novick
# 8749   s8558  TV Show                                      The West Wing
#
#                 director         country date_added  release_year rating  \
# 82       Hajime Kamegaki           Japan     150921          2008  TV-PG
# 84       Hajime Kamegaki           Japan     150921          2007  TV-PG
# 86    Hirotsugu Kawasaki           Japan     150921          2005  TV-PG
# 87       Toshiyuki Tsuru           Japan     150921          2006  TV-PG
# 181      Lasse Hallström         Germany     010921          2005  PG-13
# ...                  ...             ...        ...           ...    ...
# 8693                       United States     011117          2005  TV-14
# 8714                              Norway     010716          2007  TV-PG
# 8736                      United Kingdom     291217          2006  TV-MA
# 8748                       United States     220217          2007  TV-14
# 8749                       United States     251215          2005  TV-14
#
#       duration                                          listed_in
# 82          93  Action & Adventure, Anime Features, Internatio...
# 84          95  Action & Adventure, Anime Features, Internatio...
# 86          97  Action & Adventure, Anime Features, Internatio...
# 87          95  Action & Adventure, Anime Features, Internatio...
# 181        108                                             Dramas
# ...        ...                                                ...
# 8693         8                                        TV Comedies
# 8714         1  Docuseries, International TV Shows, Science & ...
# 8736         1  British TV Shows, Docuseries, International TV...
# 8748         1                                         Docuseries
# 8749         7                                          TV Dramas
#
# [399 rows x 10 columns]

# %%
df3 = df2[df2["release_year"]>lower_limit]

# %%
df3.shape
# Out:
# (7458, 10)

# %%
sns.boxplot(x=df3["release_year"])
# Out:
# <AxesSubplot:xlabel='release_year'>

# %%
df3["release_year"].describe()
# Out:
# count    7458.000000
# mean     2017.078842
# std         2.742873
# min      2010.000000
# 25%      2016.000000
# 50%      2017.000000
# 75%      2019.000000
# max      2021.000000
# Name: release_year, dtype: float64

# %%
upper_limit = 2019.0 + 1.5*3
lower_limit = 2016.0 - 1.5*3
print(upper_limit,"- upper_limit")
print(lower_limit,"- lower_limit")
# Out:
# 2023.5 - upper_limit
# 2011.5 - lower_limit

# %%
df3[df3["release_year"]<lower_limit]
# Out:
#      show_id     type                                        title  \
# 30       s28    Movie                                    Grown Ups
# 81       s57    Movie     Naruto Shippuden the Movie: Blood Prison
# 85       s61    Movie  Naruto Shippuden: The Movie: The Lost Tower
# 97      s337  TV Show                          Friday Night Lights
# 161     s928  TV Show                           Barney and Friends
# ...      ...      ...                                          ...
# 8724   s8374  TV Show                              The Jungle Book
# 8745   s8540  TV Show                                   The Tudors
# 8750   s8561  TV Show                                The Womanizer
# 8774   s8737  TV Show                                Who's the One
# 8779   s8756  TV Show                            Women Behind Bars
#
#              director        country date_added  release_year rating  \
# 30       Dennis Dugan  United States     200921          2010  PG-13
# 81    Masahiko Murata          Japan     150921          2011  TV-14
# 85    Masahiko Murata          Japan     150921          2010  TV-14
# 97                          Pakistan     010821          2010  TV-14
# 161                         Pakistan     010521          2010   TV-Y
# ...               ...            ...        ...           ...    ...
# 8724                           India     110519          2010  TV-Y7
# 8745                         Ireland     080118          2010  TV-MA
# 8750                           China     010916          2010  TV-MA
# 8774                          Taiwan     010117          2011  TV-14
# 8779                   United States     011116          2010  TV-14
#
#       duration                                          listed_in
# 30         103                                           Comedies
# 81         102  Action & Adventure, Anime Features, Internatio...
# 85          85  Action & Adventure, Anime Features, Internatio...
# 97           5                           TV Dramas, Teen TV Shows
# 161          2                                           Kids' TV
# ...        ...                                                ...
# 8724         1                                           Kids' TV
# 8745         4                                          TV Dramas
# 8750         1  International TV Shows, Romantic TV Shows, TV ...
# 8774         1  International TV Shows, Romantic TV Shows, TV ...
# 8779         3                         Crime TV Shows, Docuseries
#
# [377 rows x 10 columns]

# %%
df3 = df2[df2["release_year"]>lower_limit]

# %%
df3.shape
# Out:
# (7081, 10)

# %%
sns.boxplot(x=df3["release_year"])
# Out:
# <AxesSubplot:xlabel='release_year'>

# %%
sns.histplot(x=df3["release_year"], kde=True)
# Out:
# <AxesSubplot:xlabel='release_year', ylabel='Count'>

# %%
df3.to_csv("netflix_dataset.csv")
